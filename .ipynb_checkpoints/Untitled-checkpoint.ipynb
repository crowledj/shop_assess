# %%
import pandas as pd
import numpy as np,scipy as sp
import csv,os,sys
# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
input_data_csv='/Users/crowledj/Downloads/shop_data_assessment/shop_data.csv';
shop_data= pd.read_csv(input_data_csv)

# %%
#Look at size of dataset and no. of variables :
print ('Dataset:' , 'full_input_data:' , shop_data.shape);
# Out:
# Dataset: full_input_data: (1150000, 13)

# %%
## Q 1. 

purchaseSum = shop_data.groupby(['id','date']).purchaseamount.sum();
# shop_data_new = pd.concat([shop_data, purchaseSum], axis=1)

# %%
# Q.2. 
# want to peak @ the data again first 
shop_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     id  chain  dept  category     company  brand  \
# 0           0             0  86246    205     7       707  1078778070  12564
# 1           1             1  86246    205    63      6319   107654575  17876
# 2           2             2  86246    205    97      9753  1022027929      0
# 3           3             3  86246    205    25      2509   107996777  31373
# 4           4             4  86246    205    55      5555   107684070  32094
#
#          date  productsize productmeasure  purchasequantity  purchaseamount
# 0  2012-03-02         12.0             OZ                 1            7.59
# 1  2012-03-02         64.0             OZ                 1            1.59
# 2  2012-03-02          1.0             CT                 1            5.99
# 3  2012-03-02         16.0             OZ                 1            1.99
# 4  2012-03-02         16.0             OZ                 2           10.38

# %%
xd[:10]
# Out:
# id     date
# 86246  2012-03-02    210.51
#        2012-03-03     47.59
#        2012-03-04     32.38
#        2012-03-05     34.99
#        2012-03-06    182.33
#        2012-03-07     42.94
#        2012-03-08      5.49
#        2012-03-09     53.53
#        2012-03-10    106.53
#        2012-03-11     78.50
# Name: purchaseamount, dtype: float64

# %%
# 2. Create a column that shows the number of previous visits per customer. 
#num_visits= shop_data.groupby('id').count();
#shop_data['visit_count']

#shop_data.groupby('id', as_index=True).visit_count.count()
#num_visits[:50]

shop_data['visit_count'] = shop_data.groupby('id').cumcount('');
## quick check
shop_data.head(250)
shop_data.tail(1250)
# Out:
#          Unnamed: 0  Unnamed: 0.1        id  chain  dept  category  \
# 1148750     1148750       1148750  97795325      3    63      6399
# 1148751     1148751       1148751  97795325      3     9       907
# 1148752     1148752       1148752  97795325      3    64      6401
# 1148753     1148753       1148753  97795325      3    33      3303
# 1148754     1148754       1148754  97795325      3    33      3308
# 1148755     1148755       1148755  97795325      3     4       407
# 1148756     1148756       1148756  97795325      3    58      5827
# 1148757     1148757       1148757  97795325      3    10      1011
# 1148758     1148758       1148758  97795325      3    56      5620
# 1148759     1148759       1148759  97795325      3    26      2633
# 1148760     1148760       1148760  97795325      3    63      6399
# 1148761     1148761       1148761  97795325      3    26      2628
# 1148762     1148762       1148762  97795325      3    56      5609
# 1148763     1148763       1148763  97795325      3    97      9753
# 1148764     1148764       1148764  97795325      3    57      5704
# 1148765     1148765       1148765  97795325      3    99      9904
# 1148766     1148766       1148766  97795325      3    63      6320
# 1148767     1148767       1148767  97795325      3    63      6323
# 1148768     1148768       1148768  97795325      3    59      5902
# 1148769     1148769       1148769  97795325      3    37      3705
# 1148770     1148770       1148770  97795325      3    59      5902
# 1148771     1148771       1148771  97795325      3     8       818
# 1148772     1148772       1148772  97795325      3    82      8201
# 1148773                 1            1.25          136
# 1148774                 2            5.00          137
# 1148775                 1            0.39          138
# 1148776                 1            3.59          139
# 1148777                 1           22.98          140
# 1148778                 1            5.99          141
# 1148779                 2            5.00          142
# ...                   ...             ...          ...
# 1149970                 2            2.98         1333
# 1149971                 1            2.49         1334
# 1149972                 1            8.99         1335
# 1149973                 1            2.99         1336
# 1149974                 1            2.50         1337
# 1149975                 2            2.38         1338
# 1149976                 1            9.99         1339
# 1149977                 1            2.50         1340
# 1149978                 1            3.29         1341
# 1149979                 1            0.99         1342
# 1149980                 2            6.00         1343
# 1149981                 1            2.50         1344
# 1149982                 1            3.49         1345
# 1149983                 1            0.89         1346
# 1149984                 4            4.00         1347
# 1149985                 1            3.19         1348
# 1149986                 1            3.00         1349
# 1149987                 1            2.99         1350
# 1149988                 2            5.98         1351
# 1149989                 1            3.59         1352
# 1149990                 2           11.98         1353
# 1149991                 2            6.00         1354
# 1149992                 2            9.98         1355
# 1149993                 2            3.98         1356
# 1149994                 2            3.38         1357
# 1149995                 2            2.38         1358
# 1149996                 1            1.49         1359
# 1149997                 1            1.00         1360
# 1149998                 1            9.99         1361
# 1149999                 1           16.99         1362
#
# [1250 rows x 14 columns]

# %%
type(xd)
# Q 3.  ????
select count(select date from T2 where date < T1)  from table T1  where exists distinct (id)
# Out:
# pandas.core.series.Series

# %%
#Q.4 
# shop_data['purchase_rolling~Sum'] = shop_data.groupby('id','dept' == 99).cumcount('purchaseamount');
shop_data[pd.Dataframe(stuff)['dept'] == 99]['purchaseamount'].cumsum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-72eba97b22b4> in <module>
#       1 #Q.4
#       2 # shop_data['purchase_rolling~Sum'] = shop_data.groupby('id','dept' == 99).cumcount('purchaseamount');
# ----> 3 shop_data[pd.Dataframe(stuff)['dept'] == 99]['purchaseamount'].cumsum()
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
stuff= shop_data.groupby('id')

# %%
stuff

# %%
stuff

# %%
print ('Dataset:' , 'full_input_data:' , stuff.shape);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-2bdfdaf389f1> in <module>
# ----> 1 print ('Dataset:' , 'full_input_data:' , stuff.shape);
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access attribute 'shape' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
purchaseSumperDay = shop_data.groupby(['date']).purchaseamount.sum();
purchaseSumperDay.head()
# Out:
# date
# 2012-03-02    13549.83
# 2012-03-03    11718.47
# 2012-03-04    15462.87
# 2012-03-05    10567.91
# 2012-03-06    10167.25
# Name: purchaseamount, dtype: float64

# %%
# Q 8. 
plt.plot(shop_data['date'].unique(),purchaseSumperDay)

# %%
#Q. 5 

shop_data_distince_days = shop_data.drop_duplicates(subset=['date'])

# %%
shop_data_distince_days.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1     id  chain  dept  category     company  brand  \
# 0            0             0  86246    205     7       707  1078778070  12564
# 52          52            52  86246    205     8       809   101300010   8164
# 59          59            59  86246    205    36      3601   104900040   3809
# 71          71            71  86246    205    64      6408   108289686   6276
# 77          77            77  86246    205    70      7002  1030813737  25162
#
#           date  productsize productmeasure  purchasequantity  purchaseamount  \
# 0   2012-03-02        12.00             OZ                 1            7.59
# 52  2012-03-03        12.00             OZ                 1            1.29
# 59  2012-03-04        20.00             OZ                 1            1.69
# 71  2012-03-05         0.75             LT                 1            8.29
# 77  2012-03-06        30.00             CT                 1            2.39
#
#     visit_count
# 0             0
# 52           52
# 59           59
# 71           71
# 77           77

# %%
distict_visit_counter = shop_data_distince_days.groupby('id').cumcount('')

# %%
type(distict_visit_counter)
#distict_visit_counter
# Out:
# pandas.core.series.Series

# %%
#pd.Dataframe(distict_visit_counter)
#Q. 5 Continued ...
distict_visit_countDaysUniq = shop_data.groupby('id')['date'].nunique();
#distict_visit_counterCol = shop_data_distince_days.groupby('id').count();

distict_visit_countDaysUniq
# Out:
# id
# 86246       381
# 86252       368
# 12262064    237
# 12277270    184
# 12332190    113
# 12524696    161
# 12682470    141
# 12996040     39
# 13074629    147
# 13089312    132
# 13179265     92
# 13251776    134
# 13387341    147
# 13501141    132
# 13540129    254
# 13558712    116
# 13563017     97
# 13584134     56
# 13744500     94
# 13807224    152
# 13873775    112
# 13974451     19
# 14026320    112
# 14049441    119
# 14088807     52
# 14101174     30
# 14278542     77
# 14381137     39
# 14576147     76
# 14632152     33
#            ...
# 97657346    163
# 97661544    164
# 97664263     76
# 97667024     91
# 97669999     32
# 97671336     79
# 97671517    118
# 97674711     66
# 97676374     80
# 97680900     86
# 97682960     67
# 97684130     62
# 97697018    140
# 97698632    106
# 97703003    121
# 97724049    238
# 97724346     70
# 97737931     31
# 97751353     30
# 97752092    145
# 97754530     32
# 97760033     44
# 97763155    142
# 97763238     72
# 97771034    175
# 97771975    117
# 97776300     89
# 97781522    101
# 97782380     32
# 97795325    134
# Name: date, Length: 1215, dtype: int64

# %% [markdown]
# # Q5
#
# plt.plot(distict_visit_countDaysUniq[0],distict_visit_countDaysUniq[1])

# %%
#distict_visit_counter.to_frame().reset_index();
#Q5 still 
pd.Series.plot(distict_visit_countDaysUniq)

# %%
distict_visit_count = shop_data_distince_days.groupby('id').count()

# %%
distict_visit_count.head()
# Out:
#           Unnamed: 0  Unnamed: 0.1  chain  dept  category  company  brand  \
# id
# 86246            381           381    381   381       381      381    381
# 86252             31            31     31    31        31       31     31
# 12262064          40            40     40    40        40       40     40
# 12277270           5             5      5     5         5        5      5
# 12332190           5             5      5     5         5        5      5
#
#           date  productsize  productmeasure  purchasequantity  purchaseamount  \
# id
# 86246      381          381             377               381             381
# 86252       31           31              31                31              31
# 12262064    40           40              40                40              40
# 12277270     5            5               5                 5               5
# 12332190     5            5               5                 5               5
#
#           visit_count
# id
# 86246             381
# 86252              31
# 12262064           40
# 12277270            5
# 12332190            5
